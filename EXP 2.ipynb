# %%
c= float(input("enter temprature in Celsius:"))
f= c*9/5+32
print("Temprature in fahrenhit:",f)
# Out:
# enter temprature in Celsius:45
# Temprature in fahrenhit: 113.0

# %%
km= float(input("enter distance in kilometer:"))
miles = km *0.62137
print("distance in miles:",miles)
# Out:
# enter distance in kilometer:50
# distance in miles: 31.0685
