# %%
s = input("Enter a string:")
new_s=s[-1]+s[1:-1]+s[0]
print("New string:",new_s)
# Out:
# Enter a string:1256
# New string: 6251

# %%
s =input("enter a string:")
first = s[0]
new_s = first +s[1:].replace(first,"$")
print("new string:",new_s)

# %%
s=input("enter a string:")
new_s=s[:2]+s[-2:]
print("New string:",new_s)
# Out:
# enter a string:pyhon
# New string: pyon

# %%
s1=input("enter first string:")
s2=input("enter second string:")

new_s1=s2[0]+s1[1:]
new_s2=s1[0]+s2[1:]

print(new_s1+""+new_s2)
# Out:
# enter first string:python
# enter second string:goes
# gythonpoes
