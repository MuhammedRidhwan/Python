# %%
colors = input("enter colors seprated by comas:")
color_list = colors.split(",")
print("First color:",color_list[0])
print("Last color:",color_list[-1])
# Out:
# enter colors seprated by comas:GREEN,RED,YELLOW
# First color: GREEN
# Last color: YELLOW

# %%
filename = input("enter filename:")
extension = filename.split(".")[-1]
print("Extension:",extension)
# Out:
# enter filename:ridhwan
# Extension: ridhwan

# %%
numbers = input("enter numbers seprated by comma:")
num_list=[int(x) for x in numbers.split(",")]
print("List:",num_list)
print("Sum:",sum(num_list))
# Out:
# enter numbers seprated by comma:1,5,7,8,9,6,5
# List: [1, 5, 7, 8, 9, 6, 5]
# Sum: 41
